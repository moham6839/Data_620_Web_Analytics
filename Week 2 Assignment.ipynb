# %% [markdown]
# # Week 2 Assignment

# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = (8,8)

# %%
g = nx.Graph()

# %%
g.add_nodes_from(["Andre","Beverly","Ed","Carol","Diane","Fernando","Garth","Heather","Ike","Jane"])

# %%
g.add_edges_from([("Andre","Beverly"),("Andre","Carol"),("Andre","Diane"),("Andre","Fernando"),
                  ("Beverly","Diane"),("Beverly","Ed"),("Beverly","Garth"),
                  ("Carol","Diane"),("Carol","Fernando"),
                  ("Diane","Ed"),("Diane","Fernando"),("Diane","Garth"),
                  ("Ed","Garth"),
                  ("Fernando","Garth"),("Fernando","Heather"),
                  ("Garth","Heather"),
                  ("Heather","Ike"),
                  ("Ike","Jane")])

# %%
#nx.draw(g, with_labels=True)

# %%
nx.draw_networkx(g, with_labels=True)

# %%
nx.draw_networkx(g)

# %%
nx.draw_networkx(g, node_size=1000, node_color="y", font_size=12, font_family="calibri", 
                 width=2, edge_color="darkgray")
# Out:
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.
# findfont: Font family 'calibri' not found.

# %%
# Create a Krackhardt kite graph
G = nx.krackhardt_kite_graph()

# %%
# Draw the graph
plt.figure(figsize=(8, 6))
nx.draw_networkx(
    G,
    with_labels=True,
    node_color="skyblue",
    node_size=1000,
    font_size=15,
    font_color="black",
    font_weight="bold",
    edge_color="gray",
)
plt.title("Krackhardt Kite Graph", fontsize=16)
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a Krackhardt kite graph
G = nx.krackhardt_kite_graph()

# Draw the graph
plt.figure(figsize=(10, 6))  # Ensure this is not overridden in your environment
nx.draw_networkx(
    G,
    with_labels=True,
    node_color="skyblue",
    node_size=1000,
    font_size=15,
    font_color="black",
    font_weight="bold",
    edge_color="gray",
)
plt.title("Krackhardt Kite Graph", fontsize=16)
plt.show()

# %%
G = nx.petersen_graph()
subax1 = plt.subplot(121)
nx.draw_networkx(G, with_labels=True, font_weight='bold')
subax2 = plt.subplot(122)
nx.draw_shell(G, nlist=[range(5, 10), range(5)], with_labels=True, font_weight='bold')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-c1f3eeb6273d> in <module>
#       3 nx.draw_networkx(G, with_labels=True, font_weight='bold')
#       4 subax2 = plt.subplot(122)
# ----> 5 nx.draw_shell(G, nlist=[range(5, 10), range(5)], with_labels=True, font_weight='bold')
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/networkx/drawing/nx_pylab.py in draw_shell(G, **kwargs)
#    1183     if nlist is not None:
#    1184         del kwargs["nlist"]
# -> 1185     draw(G, shell_layout(G, nlist=nlist), **kwargs)
#    1186
#    1187
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/networkx/drawing/nx_pylab.py in draw(G, pos, ax, **kwds)
#     113     cf.set_facecolor("w")
#     114     if ax is None:
# --> 115         if cf._axstack() is None:
#     116             ax = cf.add_axes((0, 0, 1, 1))
#     117         else:
#
# TypeError: '_AxesStack' object is not callable

# %%
nx.draw(G, pos=nx.shell_layout(G, nlist=nlist), **kwargs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-24471a9bbbd2> in <module>
# ----> 1 nx.draw(G, pos=nx.shell_layout(G, nlist=nlist), **kwargs)
#
# NameError: name 'nlist' is not defined

# %%
G = nx.complete_graph(5)
pos = nx.shell_layout(G)
nx.draw(G, pos=pos)  # Draw the original graph
# Draw a subgraph, reusing the same node positions
nx.draw(G.subgraph([0, 1, 2]), pos=pos, node_color="red")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-ac25fca45897> in <module>
#       1 G = nx.complete_graph(5)
#       2 pos = nx.shell_layout(G)
# ----> 3 nx.draw(G, pos=pos)  # Draw the original graph
#       4 # Draw a subgraph, reusing the same node positions
#       5 nx.draw(G.subgraph([0, 1, 2]), pos=pos, node_color="red")
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/networkx/drawing/nx_pylab.py in draw(G, pos, ax, **kwds)
#     113     cf.set_facecolor("w")
#     114     if ax is None:
# --> 115         if cf._axstack() is None:
#     116             ax = cf.add_axes((0, 0, 1, 1))
#     117         else:
#
# TypeError: '_AxesStack' object is not callable

# %%
import networkx as nx
import matplotlib.pyplot as plt

G=nx.Graph()
G.add_node(1, text='foo')
G.add_node(2, text='bar')
G.add_edge(1,2)
print("Node labels: ", nx.get_node_attributes(G, 'text'))

nx.draw_networkx(nx.relabel_nodes(G, nx.get_node_attributes(G, 'text')), 
                 with_labels=True, node_color = 'orange')
plt.show();
# Out:
# Node labels:  {1: 'foo', 2: 'bar'}

# %%
pip install --upgrade networkx

# %%
# !pip install pyvis
# Out:
# Collecting pyvis
#   Downloading pyvis-0.3.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: ipython>=5.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from pyvis) (8.20.0)
# Requirement already satisfied: jinja2>=2.9.6 in /opt/anaconda3/lib/python3.11/site-packages (from pyvis) (3.1.3)
# Collecting jsonpickle>=1.4.1 (from pyvis)
#   Downloading jsonpickle-4.0.1-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: networkx>=1.11 in /opt/anaconda3/lib/python3.11/site-packages (from pyvis) (3.1)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (2.15.1)
# Requirement already satisfied: stack-data in /opt/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /opt/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (5.7.1)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (4.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jinja2>=2.9.6->pyvis) (2.1.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/anaconda3/lib/python3.11/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.11/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis) (0.2.5)
# Requirement already satisfied: executing in /opt/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=5.3.0->pyvis) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=5.3.0->pyvis) (2.0.5)
# Requirement already satisfied: pure-eval in /opt/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=5.3.0->pyvis) (0.2.2)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.11/site-packages (from asttokens->stack-data->ipython>=5.3.0->pyvis) (1.16.0)
# Downloading pyvis-0.3.2-py3-none-any.whl (756 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 10.2 MB/s eta 0:00:00 0:00:01
# Downloading jsonpickle-4.0.1-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 kB 5.1 MB/s eta 0:00:00
# Installing collected packages: jsonpickle, pyvis
# Successfully installed jsonpickle-4.0.1 pyvis-0.3.2

# %%
from pyvis.network import Network
net = Network()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-33b2d60493ef> in <module>
# ----> 1 from pyvis.network import Network
#       2 net = Network()
#
# ModuleNotFoundError: No module named 'pyvis'

# %%
import pandas as pd

# %%
import pyvis as pv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-15f3e4a5e7c7> in <module>
# ----> 1 import pyvis as pv
#
# ModuleNotFoundError: No module named 'pyvis'
